# %%
import pandas as pd
from pandas import DataFrame
from pathlib import Path
import datetime
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, roc_auc_score, accuracy_score, confusion_matrix
from sklearn import metrics
import matplotlib.pyplot as plt
from matplotlib import pyplot
 

#import file
train = pd.read_csv('/Users/ericmerdian/Desktop/Desktop/A_Summer_Research/AllTeams/training.csv')
test = pd.read_csv('/Users/ericmerdian/Desktop/Desktop/A_Summer_Research/AllTeams/testing.csv')

# #time column is not needed
# df = df.drop('Time',1)

# print(df['Possession'].isna().sum())
# #there are 1075 null values for possession

# #drop rows where possession is null
# df = df[df['Possession'].notna()]


# df['GameDatetime'] = pd.to_datetime(df['GameDate'])
# df = df.drop('GameDate',1)

#home team score and point differential
                        
train.head()
# Out:
#           GameID VisitorName      HomeName  VisitorWinPercent  HomeWinPercent  \
# 0  18_11_10_4_01     Hendrix  Texas-Dallas                0.5             0.5
# 1  18_11_10_4_01     Hendrix  Texas-Dallas                0.5             0.5
# 2  18_11_10_4_01     Hendrix  Texas-Dallas                0.5             0.5
# 3  18_11_10_4_01     Hendrix  Texas-Dallas                0.5             0.5
# 4  18_11_10_4_01     Hendrix  Texas-Dallas                0.5             0.5
#
#   Outcome  Away Team Score  Home Team Score  Point Differential  Period  \
# 0     Win                0                2                   2       1
# 1     Win                0                2                   2       1
# 2     Win                0                2                   2       1
# 3     Win                0                2                   2       1
# 4     Win                0                4                   4       1
#
#    Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  Away 3PTRs PCT  \
# 0                NaN             NaN                1.0             NaN
# 1                NaN             NaN                1.0             NaN
# 2                0.0             0.0                1.0             NaN
# 3                0.0             0.0                1.0             NaN
# 4                0.0             0.0                1.0             NaN
#
#    Time Remaining Secs
# 0                 2386
# 1                 2386
# 2                 2354
# 3                 2354
# 4                 2344

# %%
test
# Out:
#               GameID VisitorName             HomeName  VisitorWinPercent  \
# 0      19_01_04_2_13  Oglethorpe  Birmingham-Southern                0.5
# 1      19_01_04_2_13  Oglethorpe  Birmingham-Southern                0.5
# 2      19_01_04_2_13  Oglethorpe  Birmingham-Southern                0.5
# 3      19_01_04_2_13  Oglethorpe  Birmingham-Southern                0.5
# 4      19_01_04_2_13  Oglethorpe  Birmingham-Southern                0.5
# ...              ...         ...                  ...                ...
# 42222  19_02_22_4_27     Hendrix              Sewanee                0.4
# 42223  19_02_22_4_27     Hendrix              Sewanee                0.4
# 42224  19_02_22_4_27     Hendrix              Sewanee                0.4
# 42225  19_02_22_4_27     Hendrix              Sewanee                0.4
# 42226  19_02_22_4_27     Hendrix              Sewanee                0.4
#
#        HomeWinPercent Outcome  Away Team Score Home Team Score  \
# 0               0.545    Lose                0               2
# 1               0.545    Lose                0               2
# 2               0.545    Lose                0               2
# 3               0.545    Lose                0               2
# 4               0.545    Lose                0               2
# ...               ...     ...              ...             ...
# 42222           0.760     Win               64              79
# 42223           0.760     Win               64              79
# 42224           0.760     Win               64              82
# 42225           0.760     Win               64              82
# 42226           0.760     Win               64              82
#
#        Point Differential  Period  Home Shooting PCT  Home 3PTRs PCT  \
# 0                     2.0       1              1.000             NaN
# 1                     2.0       1              0.500           0.000
# 2                     2.0       1              0.500           0.000
# 3                     2.0       1              0.500           0.000
# 4                     2.0       1              0.500           0.000
# ...                   ...     ...                ...             ...
# 42222                15.0       2              0.458           0.375
# 42223                15.0       2              0.458           0.375
# 42224                18.0       2              0.458           0.375
# 42225                18.0       2              0.452           0.364
# 42226                18.0       2              0.452           0.364
#
#        Away Shooting PCT  Away 3PTRs PCT  Time Remaining Secs
# 0                    NaN             NaN                 2376
# 1                    NaN             NaN                 2344
# 2                    NaN             NaN                 2344
# 3                    NaN             NaN                 2334
# 4                    NaN             NaN                 2334
# ...                  ...             ...                  ...
# 42222              0.574           0.522                   51
# 42223              0.574           0.522                   51
# 42224              0.580           0.542                   22
# 42225              0.580           0.542                   16
# 42226              0.580           0.542                   16
#
# [42227 rows x 15 columns]

# %%
test[test['GameID'] ==  '19_01_27_2_20']
# Out:
#              GameID          VisitorName HomeName  VisitorWinPercent  \
# 2427  19_01_27_2_20  Birmingham-Southern   Centre              0.556
# 2428  19_01_27_2_20  Birmingham-Southern   Centre              0.556
# 2429  19_01_27_2_20  Birmingham-Southern   Centre              0.556
# 2430  19_01_27_2_20  Birmingham-Southern   Centre              0.556
# 2431  19_01_27_2_20  Birmingham-Southern   Centre              0.556
# ...             ...                  ...      ...                ...
# 2900  19_01_27_2_20  Birmingham-Southern   Centre              0.556
# 2901  19_01_27_2_20  Birmingham-Southern   Centre              0.556
# 2902  19_01_27_2_20  Birmingham-Southern   Centre              0.556
# 2903  19_01_27_2_20  Birmingham-Southern   Centre              0.556
# 2904  19_01_27_2_20  Birmingham-Southern   Centre              0.556
#
#       HomeWinPercent Outcome  Away Team Score Home Team Score  \
# 2427           0.842     Win                2               0
# 2428           0.842     Win                2               0
# 2429           0.842     Win                2               0
# 2430           0.842     Win                2               0
# 2431           0.842     Win                2               0
# ...              ...     ...              ...             ...
# 2900           0.842     Win               54              71
# 2901           0.842     Win               54              71
# 2902           0.842     Win               54              73
# 2903           0.842     Win               54              73
# 2904           0.842     Win               54              73
#
#       Point Differential  Period  Home Shooting PCT  Home 3PTRs PCT  \
# 2427                -2.0       1              1.000             NaN
# 2428                -2.0       1              1.000             NaN
# 2429                -2.0       1              1.000             NaN
# 2430                -2.0       1              1.000             NaN
# 2431                -2.0       1              1.000             NaN
# ...                  ...     ...                ...             ...
# 2900                17.0       2              0.467           0.269
# 2901                17.0       2              0.467           0.269
# 2902                19.0       2              0.467           0.269
# 2903                19.0       2              0.459           0.259
# 2904                19.0       2              0.459           0.259
#
#       Away Shooting PCT  Away 3PTRs PCT  Time Remaining Secs
# 2427                NaN             NaN                 2382
# 2428                NaN             NaN                 2382
# 2429              0.000             NaN                 2350
# 2430              0.000             NaN                 2350
# 2431              0.000             NaN                 2340
# ...                 ...             ...                  ...
# 2900              0.493           0.333                   36
# 2901              0.493           0.333                   36
# 2902              0.500           0.333                   30
# 2903              0.500           0.333                   20
# 2904              0.500           0.333                   20
#
# [478 rows x 15 columns]

# %%
## one-hot encode

#add win and loss column
df_add1 = pd.get_dummies(train.Outcome, prefix = 'Outcome',drop_first = True)

train = pd.concat([train,df_add1], axis=1)
test = pd.concat([test,df_add1], axis=1)

# %%
train.groupby(['GameID', 'Outcome_Win']).ngroups
# Out:
# 85

# %%
game_outcome = train.groupby(["GameID", "Outcome_Win"]).size().reset_index()

# %%
game_outcome
# Out:
#            GameID  Outcome_Win    0
# 0   18_11_06_7_01            1  571
# 1   18_11_09_6_01            1  651
# 2   18_11_09_7_02            1  536
# 3   18_11_10_2_01            1  621
# 4   18_11_10_4_01            1  502
# ..            ...          ...  ...
# 80  19_01_01_2_12            1  570
# 81  19_01_01_5_12            1  570
# 82  19_01_02_4_13            0  537
# 83  19_01_04_1_12            0  598
# 84  19_01_04_3_13            1  496
#
# [85 rows x 3 columns]

# %%
game_outcome = pd.DataFrame(game_outcome)

# %%
game_outcome
# Out:
#            GameID  Outcome_Win    0
# 0   18_11_06_7_01            1  571
# 1   18_11_09_6_01            1  651
# 2   18_11_09_7_02            1  536
# 3   18_11_10_2_01            1  621
# 4   18_11_10_4_01            1  502
# ..            ...          ...  ...
# 80  19_01_01_2_12            1  570
# 81  19_01_01_5_12            1  570
# 82  19_01_02_4_13            0  537
# 83  19_01_04_1_12            0  598
# 84  19_01_04_3_13            1  496
#
# [85 rows x 3 columns]

# %% [markdown]
# Based on the cell below, we can see that there are 24 more home games won than lost in this dataset.

# %%
game_outcome.groupby(['Outcome_Win']).size()
# Out:
# Outcome_Win
# 0    31
# 1    54
# dtype: int64

# %%
game_outcome
# Out:
#            GameID  Outcome_Win    0
# 0   18_11_06_7_01            1  571
# 1   18_11_09_6_01            1  651
# 2   18_11_09_7_02            1  536
# 3   18_11_10_2_01            1  621
# 4   18_11_10_4_01            1  502
# ..            ...          ...  ...
# 80  19_01_01_2_12            1  570
# 81  19_01_01_5_12            1  570
# 82  19_01_02_4_13            0  537
# 83  19_01_04_1_12            0  598
# 84  19_01_04_3_13            1  496
#
# [85 rows x 3 columns]

# %%
game_wins = game_outcome[game_outcome['Outcome_Win'] ==  1]
game_wins
# Out:
#            GameID  Outcome_Win    0
# 0   18_11_06_7_01            1  571
# 1   18_11_09_6_01            1  651
# 2   18_11_09_7_02            1  536
# 3   18_11_10_2_01            1  621
# 4   18_11_10_4_01            1  502
# 5   18_11_11_6_02            1  580
# 6   18_11_12_2_02            1  561
# 7   18_11_13_1_01            1  580
# 9   18_11_13_4_02            1  496
# 10  18_11_13_5_01            1  638
# 12  18_11_14_2_03            1  532
# 13  18_11_15_4_03            1  449
# 14  18_11_16_1_02            1  446
# 16  18_11_16_7_04            1  467
# 18  18_11_17_4_04            1  413
# 19  18_11_17_5_02            1  515
# 21  18_11_17_7_05            1  389
# 23  18_11_18_5_03            1  572
# 25  18_11_19_2_05            1  545
# 26  18_11_19_3_02            1  469
# 27  18_11_20_1_04            1  542
# 30  18_11_21_6_05            1  511
# 31  18_11_23_3_03            1  493
# 32  18_11_23_6_06            1  540
# 33  18_11_24_1_05            1  519
# 34  18_11_24_2_06            1  596
# 36  18_11_24_5_04            1  507
# 40  18_11_25_2_07            1  508
# 41  18_11_25_5_05            1  510
# 43  18_11_27_3_05            1  464
# 44  18_11_27_4_07            1  525
# 45  18_11_27_5_06            1  561
# 46  18_11_28_7_08            1  457
# 47  18_11_29_4_08            1  465
# 49  18_12_01_1_07            1  439
# 50  18_12_01_3_06            1  480
# 52  18_12_01_7_09            1  483
# 54  18_12_04_6_08            1  515
# 55  18_12_07_1_08            1  485
# 57  18_12_11_1_09            1  508
# 58  18_12_11_7_11            1  485
# 59  18_12_12_3_07            1  420
# 60  18_12_13_2_09            1  466
# 63  18_12_15_4_10            1  483
# 68  18_12_18_5_09            1  538
# 70  18_12_20_2_11            1  576
# 75  18_12_29_4_12            1  468
# 76  18_12_29_5_11            1  537
# 77  18_12_29_7_12            1  536
# 78  18_12_30_1_11            1  495
# 79  18_12_30_6_11            1  530
# 80  19_01_01_2_12            1  570
# 81  19_01_01_5_12            1  570
# 84  19_01_04_3_13            1  496

# %%
game_losses = game_outcome[game_outcome['Outcome_Win'] ==  0]
game_losses
# Out:
#            GameID  Outcome_Win    0
# 8   18_11_13_3_01            0  472
# 11  18_11_13_7_03            0  487
# 15  18_11_16_2_04            0  552
# 17  18_11_17_1_03            0  515
# 20  18_11_17_6_03            0   33
# 22  18_11_18_4_05            0  411
# 24  18_11_18_6_04            0  612
# 28  18_11_20_4_06            0  481
# 29  18_11_20_7_06            0  445
# 35  18_11_24_3_04            0  455
# 37  18_11_24_6_07            0  481
# 38  18_11_24_7_07            0  469
# 39  18_11_25_1_06            0  492
# 42  18_11_27_2_08            0  547
# 48  18_11_30_5_07            0  563
# 51  18_12_01_5_08            0  484
# 53  18_12_02_4_09            0  469
# 56  18_12_07_7_10            0  462
# 61  18_12_15_2_10            0  660
# 62  18_12_15_3_08            0  424
# 64  18_12_17_3_09            0  534
# 65  18_12_17_6_09            0  523
# 66  18_12_18_1_10            0  472
# 67  18_12_18_3_10            0  508
# 69  18_12_18_6_10            0  486
# 71  18_12_20_5_10            0  582
# 72  18_12_28_3_11            0  571
# 73  18_12_29_3_12            0  524
# 74  18_12_29_4_11            0  525
# 82  19_01_02_4_13            0  537
# 83  19_01_04_1_12            0  598

# %% [markdown]
# Because we want to have the same amount of wins as losses and there were 31 games lost by the home team in our training data, I then extracted 31 random game id's from the games won by the home team.

# %%
remove_n = 31
drop_indices = np.random.choice(game_wins.index, remove_n, replace=False)
df_subset = game_wins.drop(drop_indices)

# %%
len(df_subset)
# Out:
# 23

# %%
remaining_games = df_subset['GameID']
remaining_games = pd.DataFrame(remaining_games)

# %%
len(remaining_games)
# Out:
# 23

# %% [markdown]
# After all was said and done, we were left with 23 games won by the home team to filter out of our training set.

# %%
game_ids = remaining_games['GameID'].unique()
game_ids
# Out:
# array(['18_11_10_4_01', '18_11_13_1_01', '18_11_13_5_01', '18_11_14_2_03',
#        '18_11_17_4_04', '18_11_17_7_05', '18_11_19_2_05', '18_11_21_6_05',
#        '18_11_24_1_05', '18_11_25_2_07', '18_11_27_3_05', '18_11_27_4_07',
#        '18_11_28_7_08', '18_11_29_4_08', '18_12_01_7_09', '18_12_11_1_09',
#        '18_12_11_7_11', '18_12_12_3_07', '18_12_15_4_10', '18_12_29_4_12',
#        '18_12_29_5_11', '18_12_30_6_11', '19_01_01_2_12'], dtype=object)

# %%
len(game_ids)
# Out:
# 23

# %%
b = np.asarray(game_ids)
b
# Out:
# array(['18_11_10_4_01', '18_11_13_1_01', '18_11_13_5_01', '18_11_14_2_03',
#        '18_11_17_4_04', '18_11_17_7_05', '18_11_19_2_05', '18_11_21_6_05',
#        '18_11_24_1_05', '18_11_25_2_07', '18_11_27_3_05', '18_11_27_4_07',
#        '18_11_28_7_08', '18_11_29_4_08', '18_12_01_7_09', '18_12_11_1_09',
#        '18_12_11_7_11', '18_12_12_3_07', '18_12_15_4_10', '18_12_29_4_12',
#        '18_12_29_5_11', '18_12_30_6_11', '19_01_01_2_12'], dtype=object)

# %% [markdown]
# We have now set our training set to contain 31 games won by the home team and 31 games lost by the home team.

# %%
train = train.loc[~train['GameID'].isin(b)]
train
# Out:
#               GameID        VisitorName HomeName  VisitorWinPercent  \
# 502    18_11_13_4_02            Hendrix     UAFS                0.5
# 503    18_11_13_4_02            Hendrix     UAFS                0.5
# 504    18_11_13_4_02            Hendrix     UAFS                0.5
# 505    18_11_13_4_02            Hendrix     UAFS                0.5
# 506    18_11_13_4_02            Hendrix     UAFS                0.5
# ...              ...                ...      ...                ...
# 43180  18_12_29_7_12  Bridgewater (Va.)  Sewanee                0.5
# 43181  18_12_29_7_12  Bridgewater (Va.)  Sewanee                0.5
# 43182  18_12_29_7_12  Bridgewater (Va.)  Sewanee                0.5
# 43183  18_12_29_7_12  Bridgewater (Va.)  Sewanee                0.5
# 43184  18_12_29_7_12  Bridgewater (Va.)  Sewanee                0.5
#
#        HomeWinPercent Outcome  Away Team Score  Home Team Score  \
# 502               0.5     Win                0                3
# 503               0.5     Win                0                3
# 504               0.5     Win                0                3
# 505               0.5     Win                0                3
# 506               0.5     Win                0                5
# ...               ...     ...              ...              ...
# 43180             0.9     Win               76               79
# 43181             0.9     Win               76               79
# 43182             0.9     Win               76               79
# 43183             0.9     Win               76               79
# 43184             0.9     Win               76               79
#
#        Point Differential  Period  Home Shooting PCT  Home 3PTRs PCT  \
# 502                     3       1                NaN             NaN
# 503                     3       1                NaN             NaN
# 504                     3       1                NaN             NaN
# 505                     3       1                NaN             NaN
# 506                     5       1                NaN             NaN
# ...                   ...     ...                ...             ...
# 43180                   3       2              0.477           0.269
# 43181                   3       2              0.477           0.269
# 43182                   3       2              0.477           0.269
# 43183                   3       2              0.477           0.269
# 43184                   3       2              0.472           0.259
#
#        Away Shooting PCT  Away 3PTRs PCT  Time Remaining Secs  Outcome_Win
# 502                1.000           1.000                 2374            1
# 503                1.000           1.000                 2374            1
# 504                1.000           1.000                 2348            1
# 505                1.000           1.000                 2347            1
# 506                1.000           1.000                 2345            1
# ...                  ...             ...                  ...          ...
# 43180              0.511           0.368                    9            1
# 43181              0.511           0.368                    9            1
# 43182              0.511           0.368                    9            1
# 43183              0.511           0.368                    9            1
# 43184              0.511           0.368                    3            1
#
# [31653 rows x 16 columns]

# %%
test_copy = test

# %%
test_copy
# Out:
#               GameID VisitorName             HomeName  VisitorWinPercent  \
# 0      19_01_04_2_13  Oglethorpe  Birmingham-Southern                0.5
# 1      19_01_04_2_13  Oglethorpe  Birmingham-Southern                0.5
# 2      19_01_04_2_13  Oglethorpe  Birmingham-Southern                0.5
# 3      19_01_04_2_13  Oglethorpe  Birmingham-Southern                0.5
# 4      19_01_04_2_13  Oglethorpe  Birmingham-Southern                0.5
# ...              ...         ...                  ...                ...
# 43180            NaN         NaN                  NaN                NaN
# 43181            NaN         NaN                  NaN                NaN
# 43182            NaN         NaN                  NaN                NaN
# 43183            NaN         NaN                  NaN                NaN
# 43184            NaN         NaN                  NaN                NaN
#
#        HomeWinPercent Outcome  Away Team Score Home Team Score  \
# 0               0.545    Lose              0.0               2
# 1               0.545    Lose              0.0               2
# 2               0.545    Lose              0.0               2
# 3               0.545    Lose              0.0               2
# 4               0.545    Lose              0.0               2
# ...               ...     ...              ...             ...
# 43180             NaN     NaN              NaN             NaN
# 43181             NaN     NaN              NaN             NaN
# 43182             NaN     NaN              NaN             NaN
# 43183             NaN     NaN              NaN             NaN
# 43184             NaN     NaN              NaN             NaN
#
#        Point Differential  Period  Home Shooting PCT  Home 3PTRs PCT  \
# 0                     2.0     1.0                1.0             NaN
# 1                     2.0     1.0                0.5             0.0
# 2                     2.0     1.0                0.5             0.0
# 3                     2.0     1.0                0.5             0.0
# 4                     2.0     1.0                0.5             0.0
# ...                   ...     ...                ...             ...
# 43180                 NaN     NaN                NaN             NaN
# 43181                 NaN     NaN                NaN             NaN
# 43182                 NaN     NaN                NaN             NaN
# 43183                 NaN     NaN                NaN             NaN
# 43184                 NaN     NaN                NaN             NaN
#
#        Away Shooting PCT  Away 3PTRs PCT  Time Remaining Secs  Outcome_Win
# 0                    NaN             NaN               2376.0            1
# 1                    NaN             NaN               2344.0            1
# 2                    NaN             NaN               2344.0            1
# 3                    NaN             NaN               2334.0            1
# 4                    NaN             NaN               2334.0            1
# ...                  ...             ...                  ...          ...
# 43180                NaN             NaN                  NaN            1
# 43181                NaN             NaN                  NaN            1
# 43182                NaN             NaN                  NaN            1
# 43183                NaN             NaN                  NaN            1
# 43184                NaN             NaN                  NaN            1
#
# [43185 rows x 16 columns]

# %%
#drop columns that are not used
unused_columns = ['GameID','VisitorName','HomeName', 'Outcome', 'Away Team Score']

train = train.drop(unused_columns, axis = 1)
test = test.drop(unused_columns, axis = 1)

train.head()
# Out:
#      VisitorWinPercent  HomeWinPercent  Home Team Score  Point Differential  \
# 502                0.5             0.5                3                   3
# 503                0.5             0.5                3                   3
# 504                0.5             0.5                3                   3
# 505                0.5             0.5                3                   3
# 506                0.5             0.5                5                   5
#
#      Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# 502       1                NaN             NaN                1.0
# 503       1                NaN             NaN                1.0
# 504       1                NaN             NaN                1.0
# 505       1                NaN             NaN                1.0
# 506       1                NaN             NaN                1.0
#
#      Away 3PTRs PCT  Time Remaining Secs  Outcome_Win
# 502             1.0                 2374            1
# 503             1.0                 2374            1
# 504             1.0                 2348            1
# 505             1.0                 2347            1
# 506             1.0                 2345            1

# %%
train.describe()
# Out:
#        VisitorWinPercent  HomeWinPercent  Home Team Score  Point Differential  \
# count       31653.000000    31653.000000     31653.000000        31653.000000
# mean            0.555724        0.498907        37.703219            0.164029
# std             0.204761        0.194337        23.282373           12.443762
# min             0.000000        0.000000         0.000000          -50.000000
# 25%             0.500000        0.500000        18.000000           -7.000000
# 50%             0.500000        0.500000        36.000000            0.000000
# 75%             0.556000        0.500000        56.000000            6.000000
# max             1.000000        1.000000       103.000000           48.000000
#
#              Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# count  31653.000000       31446.000000    30865.000000       24764.000000
# mean       1.531830           0.477780        0.343009           0.480087
# std        0.527554           0.121448        0.183939           0.118943
# min        1.000000           0.000000        0.000000           0.000000
# 25%        1.000000           0.412000        0.250000           0.425000
# 50%        2.000000           0.484000        0.333000           0.486000
# 75%        2.000000           0.550000        0.417000           0.540000
# max        4.000000           1.000000        1.000000           1.000000
#
#        Away 3PTRs PCT  Time Remaining Secs   Outcome_Win
# count    24333.000000         31653.000000  31653.000000
# mean         0.306670          1144.485799      0.514296
# std          0.161249           697.171806      0.499803
# min          0.000000             0.000000      0.000000
# 25%          0.222000           532.000000      0.000000
# 50%          0.308000          1162.000000      1.000000
# 75%          0.393000          1747.000000      1.000000
# max          1.000000          2400.000000      1.000000

# %% [markdown]
# Now that the number of games has been balanced out, it was important to check that the number of rows also balanced our (roughly). Here we can see there are about 600 additional rows for the home team won games, but not a huge deal.

# %%
train.groupby(['Outcome_Win']).size()
# Out:
# Outcome_Win
# 0    15374
# 1    16279
# dtype: int64

# %%
test.head()
# Out:
#    VisitorWinPercent  HomeWinPercent Home Team Score  Point Differential  \
# 0                0.5           0.545               2                 2.0
# 1                0.5           0.545               2                 2.0
# 2                0.5           0.545               2                 2.0
# 3                0.5           0.545               2                 2.0
# 4                0.5           0.545               2                 2.0
#
#    Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# 0     1.0                1.0             NaN                NaN
# 1     1.0                0.5             0.0                NaN
# 2     1.0                0.5             0.0                NaN
# 3     1.0                0.5             0.0                NaN
# 4     1.0                0.5             0.0                NaN
#
#    Away 3PTRs PCT  Time Remaining Secs  Outcome_Win
# 0             NaN               2376.0            1
# 1             NaN               2344.0            1
# 2             NaN               2344.0            1
# 3             NaN               2334.0            1
# 4             NaN               2334.0            1

# %%
test = test[test['Home Team Score'] != '(+5)']

# %%
test_copy = test_copy[test_copy['Home Team Score'] != '(+5)']

# %%
test_copy = test_copy[test_copy['Home Team Score'] != '(+1)']

# %%
test = test[test['Home Team Score'] != '(+1)']

# %%
test
# Out:
#        VisitorWinPercent  HomeWinPercent Home Team Score  Point Differential  \
# 0                    0.5           0.545               2                 2.0
# 1                    0.5           0.545               2                 2.0
# 2                    0.5           0.545               2                 2.0
# 3                    0.5           0.545               2                 2.0
# 4                    0.5           0.545               2                 2.0
# ...                  ...             ...             ...                 ...
# 43180                NaN             NaN             NaN                 NaN
# 43181                NaN             NaN             NaN                 NaN
# 43182                NaN             NaN             NaN                 NaN
# 43183                NaN             NaN             NaN                 NaN
# 43184                NaN             NaN             NaN                 NaN
#
#        Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# 0         1.0                1.0             NaN                NaN
# 1         1.0                0.5             0.0                NaN
# 2         1.0                0.5             0.0                NaN
# 3         1.0                0.5             0.0                NaN
# 4         1.0                0.5             0.0                NaN
# ...       ...                ...             ...                ...
# 43180     NaN                NaN             NaN                NaN
# 43181     NaN                NaN             NaN                NaN
# 43182     NaN                NaN             NaN                NaN
# 43183     NaN                NaN             NaN                NaN
# 43184     NaN                NaN             NaN                NaN
#
#        Away 3PTRs PCT  Time Remaining Secs  Outcome_Win
# 0                 NaN               2376.0            1
# 1                 NaN               2344.0            1
# 2                 NaN               2344.0            1
# 3                 NaN               2334.0            1
# 4                 NaN               2334.0            1
# ...               ...                  ...          ...
# 43180             NaN                  NaN            1
# 43181             NaN                  NaN            1
# 43182             NaN                  NaN            1
# 43183             NaN                  NaN            1
# 43184             NaN                  NaN            1
#
# [43179 rows x 11 columns]

# %%
test = test.dropna()

# %%
test_copy = test_copy.dropna()

# %%
len(test)
# Out:
# 30146

# %%
len(test_copy)
# Out:
# 30146

# %%
train = train.fillna(train.mean())

# %%
test = test.fillna(train.mean())

# %%
y_train = train['Outcome_Win']
y_test = test['Outcome_Win']

# %%
X_train = train.drop(['Outcome_Win'], axis = 1)
X_test = test.drop(['Outcome_Win'], axis = 1)

X_train
# Out:
#        VisitorWinPercent  HomeWinPercent  Home Team Score  Point Differential  \
# 502                  0.5             0.5                3                   3
# 503                  0.5             0.5                3                   3
# 504                  0.5             0.5                3                   3
# 505                  0.5             0.5                3                   3
# 506                  0.5             0.5                5                   5
# ...                  ...             ...              ...                 ...
# 43180                0.5             0.9               79                   3
# 43181                0.5             0.9               79                   3
# 43182                0.5             0.9               79                   3
# 43183                0.5             0.9               79                   3
# 43184                0.5             0.9               79                   3
#
#        Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# 502         1            0.47778        0.343009              1.000
# 503         1            0.47778        0.343009              1.000
# 504         1            0.47778        0.343009              1.000
# 505         1            0.47778        0.343009              1.000
# 506         1            0.47778        0.343009              1.000
# ...       ...                ...             ...                ...
# 43180       2            0.47700        0.269000              0.511
# 43181       2            0.47700        0.269000              0.511
# 43182       2            0.47700        0.269000              0.511
# 43183       2            0.47700        0.269000              0.511
# 43184       2            0.47200        0.259000              0.511
#
#        Away 3PTRs PCT  Time Remaining Secs
# 502             1.000                 2374
# 503             1.000                 2374
# 504             1.000                 2348
# 505             1.000                 2347
# 506             1.000                 2345
# ...               ...                  ...
# 43180           0.368                    9
# 43181           0.368                    9
# 43182           0.368                    9
# 43183           0.368                    9
# 43184           0.368                    3
#
# [31653 rows x 10 columns]

# %%
X_test
# Out:
#        VisitorWinPercent  HomeWinPercent Home Team Score  Point Differential  \
# 2435               0.556           0.842               0                -5.0
# 2436               0.556           0.842               0                -5.0
# 2437               0.556           0.842               3                -2.0
# 2438               0.556           0.842               3                -2.0
# 2439               0.556           0.842               3                -2.0
# ...                  ...             ...             ...                 ...
# 42222              0.400           0.760              79                15.0
# 42223              0.400           0.760              79                15.0
# 42224              0.400           0.760              82                18.0
# 42225              0.400           0.760              82                18.0
# 42226              0.400           0.760              82                18.0
#
#        Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# 2435      1.0              1.000           1.000              0.000
# 2436      1.0              1.000           1.000              0.000
# 2437      1.0              1.000           1.000              0.333
# 2438      1.0              1.000           1.000              0.333
# 2439      1.0              1.000           1.000              0.333
# ...       ...                ...             ...                ...
# 42222     2.0              0.458           0.375              0.574
# 42223     2.0              0.458           0.375              0.574
# 42224     2.0              0.458           0.375              0.580
# 42225     2.0              0.452           0.364              0.580
# 42226     2.0              0.452           0.364              0.580
#
#        Away 3PTRs PCT  Time Remaining Secs
# 2435            0.000               2304.0
# 2436            0.000               2304.0
# 2437            0.500               2278.0
# 2438            0.500               2278.0
# 2439            0.500               2260.0
# ...               ...                  ...
# 42222           0.522                 51.0
# 42223           0.522                 51.0
# 42224           0.542                 22.0
# 42225           0.542                 16.0
# 42226           0.542                 16.0
#
# [30146 rows x 10 columns]

# %%
test_game_ids = test_copy['GameID']

# %% [markdown]
# train = train.drop('GameID', axis = 1)
# test = test.drop('GameID', axis = 1)

# %%
std_scaler = StandardScaler()
min_max_scaler = MinMaxScaler()

X_train_scaled= std_scaler.fit_transform(X_train)
X_test_scaled= std_scaler.transform(X_test)

X_train_scaled
# Out:
# array([[-0.27214792,  0.00562325, -1.49055975, ...,  4.94193163,
#          4.90412039,  1.76360205],
#        [-0.27214792,  0.00562325, -1.49055975, ...,  4.94193163,
#          4.90412039,  1.76360205],
#        [-0.27214792,  0.00562325, -1.49055975, ...,  4.94193163,
#          4.90412039,  1.72630792],
#        ...,
#        [-0.27214792,  2.06393706,  1.77376394, ...,  0.29383333,
#          0.43380643, -1.62872871],
#        [-0.27214792,  2.06393706,  1.77376394, ...,  0.29383333,
#          0.43380643, -1.62872871],
#        [-0.27214792,  2.06393706,  1.77376394, ...,  0.29383333,
#          0.43380643, -1.63733505]])

# %%
X_test_scaled
# Out:
# array([[ 1.34589282e-03,  1.76548155e+00, -1.61941463e+00, ...,
#         -4.56338186e+00, -2.16916120e+00,  1.66319479e+00],
#        [ 1.34589282e-03,  1.76548155e+00, -1.61941463e+00, ...,
#         -4.56338186e+00, -2.16916120e+00,  1.66319479e+00],
#        [ 1.34589282e-03,  1.76548155e+00, -1.49055975e+00, ...,
#         -1.39811247e+00,  1.36747960e+00,  1.62590067e+00],
#        ...,
#        [-7.60529732e-01,  1.34352722e+00,  1.90261882e+00, ...,
#          9.49699960e-01,  1.66455742e+00, -1.61008165e+00],
#        [-7.60529732e-01,  1.34352722e+00,  1.90261882e+00, ...,
#          9.49699960e-01,  1.66455742e+00, -1.61868798e+00],
#        [-7.60529732e-01,  1.34352722e+00,  1.90261882e+00, ...,
#          9.49699960e-01,  1.66455742e+00, -1.61868798e+00]])

# %%
logreg = LogisticRegression()

# fit the model with data
logreg.fit(X_train,y_train)

try:
    y_pred=logreg.predict(X_test)
except:
    print("error")
# Out:
# /Users/ericmerdian/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[ 3609,  8150],
#        [ 5828, 12559]])

# %% [markdown]
# Compared to the previous model that simply spit out that the home team always won, this is a significant improvement, albeit one that still needs work.

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("F1 Score:",metrics.f1_score(y_test, y_pred))
print("AUC Score:",metrics.roc_auc_score(y_test, y_pred))
# print("R^2 value: ", logreg.score(X_test.values.reshape(-1, 1), y_test))
# Out:
# Accuracy: 0.5363232269621176
# Precision: 0.6064513013665556
# Recall: 0.6830369282645348
# F1 Score: 0.6424698178841824
# AUC Score: 0.49497539074167296

# %%
X_test
# Out:
#        VisitorWinPercent  HomeWinPercent Home Team Score  Point Differential  \
# 2435               0.556           0.842               0                -5.0
# 2436               0.556           0.842               0                -5.0
# 2437               0.556           0.842               3                -2.0
# 2438               0.556           0.842               3                -2.0
# 2439               0.556           0.842               3                -2.0
# ...                  ...             ...             ...                 ...
# 42222              0.400           0.760              79                15.0
# 42223              0.400           0.760              79                15.0
# 42224              0.400           0.760              82                18.0
# 42225              0.400           0.760              82                18.0
# 42226              0.400           0.760              82                18.0
#
#        Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# 2435      1.0              1.000           1.000              0.000
# 2436      1.0              1.000           1.000              0.000
# 2437      1.0              1.000           1.000              0.333
# 2438      1.0              1.000           1.000              0.333
# 2439      1.0              1.000           1.000              0.333
# ...       ...                ...             ...                ...
# 42222     2.0              0.458           0.375              0.574
# 42223     2.0              0.458           0.375              0.574
# 42224     2.0              0.458           0.375              0.580
# 42225     2.0              0.452           0.364              0.580
# 42226     2.0              0.452           0.364              0.580
#
#        Away 3PTRs PCT  Time Remaining Secs   WinProb         GameID
# 2435            0.000               2304.0  0.906766  19_01_27_2_20
# 2436            0.000               2304.0  0.906766  19_01_27_2_20
# 2437            0.500               2278.0  0.799257  19_01_27_2_20
# 2438            0.500               2278.0  0.799257  19_01_27_2_20
# 2439            0.500               2260.0  0.800062  19_01_27_2_20
# ...               ...                  ...       ...            ...
# 42222           0.522                 51.0  0.980118  19_02_22_4_27
# 42223           0.522                 51.0  0.980118  19_02_22_4_27
# 42224           0.542                 22.0  0.988547  19_02_22_4_27
# 42225           0.542                 16.0  0.988447  19_02_22_4_27
# 42226           0.542                 16.0  0.988447  19_02_22_4_27
#
# [30146 rows x 12 columns]

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=uint8)

# %%
y_test
# Out:
# 2435     0
# 2436     0
# 2437     0
# 2438     0
# 2439     0
#         ..
# 42222    1
# 42223    1
# 42224    1
# 42225    1
# 42226    1
# Name: Outcome_Win, Length: 30146, dtype: uint8

# %%
X_test
# Out:
#        VisitorWinPercent  HomeWinPercent Home Team Score  Point Differential  \
# 2435               0.556           0.842               0                -5.0
# 2436               0.556           0.842               0                -5.0
# 2437               0.556           0.842               3                -2.0
# 2438               0.556           0.842               3                -2.0
# 2439               0.556           0.842               3                -2.0
# ...                  ...             ...             ...                 ...
# 42222              0.400           0.760              79                15.0
# 42223              0.400           0.760              79                15.0
# 42224              0.400           0.760              82                18.0
# 42225              0.400           0.760              82                18.0
# 42226              0.400           0.760              82                18.0
#
#        Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# 2435      1.0              1.000           1.000              0.000
# 2436      1.0              1.000           1.000              0.000
# 2437      1.0              1.000           1.000              0.333
# 2438      1.0              1.000           1.000              0.333
# 2439      1.0              1.000           1.000              0.333
# ...       ...                ...             ...                ...
# 42222     2.0              0.458           0.375              0.574
# 42223     2.0              0.458           0.375              0.574
# 42224     2.0              0.458           0.375              0.580
# 42225     2.0              0.452           0.364              0.580
# 42226     2.0              0.452           0.364              0.580
#
#        Away 3PTRs PCT  Time Remaining Secs   WinProb         GameID
# 2435            0.000               2304.0  0.906766  19_01_27_2_20
# 2436            0.000               2304.0  0.906766  19_01_27_2_20
# 2437            0.500               2278.0  0.799257  19_01_27_2_20
# 2438            0.500               2278.0  0.799257  19_01_27_2_20
# 2439            0.500               2260.0  0.800062  19_01_27_2_20
# ...               ...                  ...       ...            ...
# 42222           0.522                 51.0  0.980118  19_02_22_4_27
# 42223           0.522                 51.0  0.980118  19_02_22_4_27
# 42224           0.542                 22.0  0.988547  19_02_22_4_27
# 42225           0.542                 16.0  0.988447  19_02_22_4_27
# 42226           0.542                 16.0  0.988447  19_02_22_4_27
#
# [30146 rows x 12 columns]

# %%
len(y_pred)
# Out:
# 30146

# %%
data_outcome = pd.DataFrame((y_test == 1) & (y_pred == 0))
data_outcome
# Out:
#        Outcome_Win
# 2435         False
# 2436         False
# 2437         False
# 2438         False
# 2439         False
# ...            ...
# 42222        False
# 42223        False
# 42224        False
# 42225        False
# 42226        False
#
# [30146 rows x 1 columns]

# %%
data_outcome.groupby(['Outcome_Win']).size()
# Out:
# Outcome_Win
# False    24318
# True      5828
# dtype: int64

# %% [markdown]
# I found the following code online and it has run beofre but doesn't currently for some reason.

# %%
clf = LogisticRegression(random_state = 42, max_iter=1000)
clf.fit(X_train,y_train)
classes = logreg.predict(X_test)
probs = logreg.predict_proba(X_test)
print(np.bincount(classes))
# Out:
# [ 9437 20709]

# %%
importance = logreg.coef_
print(importance)
# summarize feature importance
# for i,v in enumerate(importance):
# 	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# [[-2.62080379e+00  3.66737310e+00 -1.05648991e-02  2.04632436e-01
#    2.99705869e-01  4.24738123e-01  2.61223121e-01 -1.01233789e+00
#   -1.48980078e+00 -1.67183109e-04]]

# %% [markdown]
# Insert a bar chart of these values * 100

# %%
cols = []
for i in X_train.columns:
    cols.append(i)

# %%
cols
# Out:
# ['VisitorWinPercent',
#  'HomeWinPercent',
#  'Home Team Score',
#  'Point Differential',
#  'Period',
#  'Home Shooting PCT',
#  'Home 3PTRs PCT',
#  'Away Shooting PCT',
#  'Away 3PTRs PCT',
#  'Time Remaining Secs']

# %%
plt.figure(figsize=(20,7))
plt.scatter(cols,importance,c='b')

# %% [markdown]
# pyplot.bar([x for x in range(len(importance))], importance)
# pyplot.show()

# %% [markdown]
# clf = LogisticRegression(random_state = 42, max_iter=1000)
# clf.fit(X_train,y_train)
# classes = model.predict(X_test)
# probs = model.predict_proba(X_test)
# print(np.bincount(classes))

# %%
win_prob = clf.predict_proba(X_test)
win_prob
# Out:
# array([[0.09323425, 0.90676575],
#        [0.09323425, 0.90676575],
#        [0.20074273, 0.79925727],
#        ...,
#        [0.01145335, 0.98854665],
#        [0.01155324, 0.98844676],
#        [0.01155324, 0.98844676]])

# %%
win_prob = pd.DataFrame(win_prob)

# %%
win_prob = win_prob[1]

# %%
win_prob
# Out:
# 0        0.906766
# 1        0.906766
# 2        0.799257
# 3        0.799257
# 4        0.800062
#            ...
# 30141    0.980118
# 30142    0.980118
# 30143    0.988547
# 30144    0.988447
# 30145    0.988447
# Name: 1, Length: 30146, dtype: float64

# %%
win_prob = clf.predict_proba(X_test)[:,1]

# %%
len(X_test)
# Out:
# 30146

# %%
sub = X_test

# %%
X_test
# Out:
#        VisitorWinPercent  HomeWinPercent Home Team Score  Point Differential  \
# 2435               0.556           0.842               0                -5.0
# 2436               0.556           0.842               0                -5.0
# 2437               0.556           0.842               3                -2.0
# 2438               0.556           0.842               3                -2.0
# 2439               0.556           0.842               3                -2.0
# ...                  ...             ...             ...                 ...
# 42222              0.400           0.760              79                15.0
# 42223              0.400           0.760              79                15.0
# 42224              0.400           0.760              82                18.0
# 42225              0.400           0.760              82                18.0
# 42226              0.400           0.760              82                18.0
#
#        Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# 2435      1.0              1.000           1.000              0.000
# 2436      1.0              1.000           1.000              0.000
# 2437      1.0              1.000           1.000              0.333
# 2438      1.0              1.000           1.000              0.333
# 2439      1.0              1.000           1.000              0.333
# ...       ...                ...             ...                ...
# 42222     2.0              0.458           0.375              0.574
# 42223     2.0              0.458           0.375              0.574
# 42224     2.0              0.458           0.375              0.580
# 42225     2.0              0.452           0.364              0.580
# 42226     2.0              0.452           0.364              0.580
#
#        Away 3PTRs PCT  Time Remaining Secs
# 2435            0.000               2304.0
# 2436            0.000               2304.0
# 2437            0.500               2278.0
# 2438            0.500               2278.0
# 2439            0.500               2260.0
# ...               ...                  ...
# 42222           0.522                 51.0
# 42223           0.522                 51.0
# 42224           0.542                 22.0
# 42225           0.542                 16.0
# 42226           0.542                 16.0
#
# [30146 rows x 10 columns]

# %%
X_test.loc[X_test['Period'] == 4]
# Out:
#        VisitorWinPercent  HomeWinPercent Home Team Score  Point Differential  \
# 3412               0.526           0.550              78                 0.0
# 3413               0.526           0.550              78                 0.0
# 3414               0.526           0.550              78                 0.0
# 3415               0.526           0.550              78                 0.0
# 3416               0.526           0.550              80                 2.0
# ...                  ...             ...             ...                 ...
# 10526              0.476           0.571              72                -5.0
# 10527              0.476           0.571              72                -5.0
# 10528              0.476           0.571              73                -4.0
# 10529              0.476           0.571              73                -4.0
# 10530              0.476           0.571              73                -4.0
#
#        Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# 3412      4.0               0.50           0.407              0.500
# 3413      4.0               0.50           0.407              0.500
# 3414      4.0               0.50           0.407              0.500
# 3415      4.0               0.50           0.407              0.500
# 3416      4.0               0.50           0.407              0.506
# ...       ...                ...             ...                ...
# 10526     4.0               0.45           0.179              0.475
# 10527     4.0               0.45           0.179              0.475
# 10528     4.0               0.45           0.179              0.479
# 10529     4.0               0.45           0.179              0.475
# 10530     4.0               0.45           0.179              0.475
#
#        Away 3PTRs PCT  Time Remaining Secs
# 3412            0.385                300.0
# 3413            0.385                300.0
# 3414            0.385                300.0
# 3415            0.385                300.0
# 3416            0.385                294.0
# ...               ...                  ...
# 10526           0.167                  2.0
# 10527           0.167                  0.0
# 10528           0.167                  0.0
# 10529           0.167                  0.0
# 10530           0.167                  0.0
#
# [196 rows x 10 columns]

# %%
sub = pd.DataFrame(sub)

# %%
win_prob
# Out:
# array([0.90676575, 0.90676575, 0.79925727, ..., 0.98854665, 0.98844676,
#        0.98844676])

# %%
sub['WinProb'] = win_prob

# %%
sub['GameID'] = test_game_ids

# %%
sub
# Out:
#        VisitorWinPercent  HomeWinPercent Home Team Score  Point Differential  \
# 2435               0.556           0.842               0                -5.0
# 2436               0.556           0.842               0                -5.0
# 2437               0.556           0.842               3                -2.0
# 2438               0.556           0.842               3                -2.0
# 2439               0.556           0.842               3                -2.0
# ...                  ...             ...             ...                 ...
# 42222              0.400           0.760              79                15.0
# 42223              0.400           0.760              79                15.0
# 42224              0.400           0.760              82                18.0
# 42225              0.400           0.760              82                18.0
# 42226              0.400           0.760              82                18.0
#
#        Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# 2435      1.0              1.000           1.000              0.000
# 2436      1.0              1.000           1.000              0.000
# 2437      1.0              1.000           1.000              0.333
# 2438      1.0              1.000           1.000              0.333
# 2439      1.0              1.000           1.000              0.333
# ...       ...                ...             ...                ...
# 42222     2.0              0.458           0.375              0.574
# 42223     2.0              0.458           0.375              0.574
# 42224     2.0              0.458           0.375              0.580
# 42225     2.0              0.452           0.364              0.580
# 42226     2.0              0.452           0.364              0.580
#
#        Away 3PTRs PCT  Time Remaining Secs   WinProb         GameID
# 2435            0.000               2304.0  0.906766  19_01_27_2_20
# 2436            0.000               2304.0  0.906766  19_01_27_2_20
# 2437            0.500               2278.0  0.799257  19_01_27_2_20
# 2438            0.500               2278.0  0.799257  19_01_27_2_20
# 2439            0.500               2260.0  0.800062  19_01_27_2_20
# ...               ...                  ...       ...            ...
# 42222           0.522                 51.0  0.980118  19_02_22_4_27
# 42223           0.522                 51.0  0.980118  19_02_22_4_27
# 42224           0.542                 22.0  0.988547  19_02_22_4_27
# 42225           0.542                 16.0  0.988447  19_02_22_4_27
# 42226           0.542                 16.0  0.988447  19_02_22_4_27
#
# [30146 rows x 12 columns]

# %%
sub[sub['GameID'] == '19_02_22_4_27']
# Out:
#        VisitorWinPercent  HomeWinPercent Home Team Score  Point Differential  \
# 41802                0.4            0.76               2                 2.0
# 41803                0.4            0.76               2                 2.0
# 41804                0.4            0.76               2                 2.0
# 41805                0.4            0.76               2                 2.0
# 41806                0.4            0.76               2                 2.0
# ...                  ...             ...             ...                 ...
# 42222                0.4            0.76              79                15.0
# 42223                0.4            0.76              79                15.0
# 42224                0.4            0.76              82                18.0
# 42225                0.4            0.76              82                18.0
# 42226                0.4            0.76              82                18.0
#
#        Period  Home Shooting PCT  Home 3PTRs PCT  Away Shooting PCT  \
# 41802     1.0              0.000           0.000              0.500
# 41803     1.0              0.000           0.000              0.500
# 41804     1.0              0.000           0.000              0.500
# 41805     1.0              0.000           0.000              0.500
# 41806     1.0              0.000           0.000              0.333
# ...       ...                ...             ...                ...
# 42222     2.0              0.458           0.375              0.574
# 42223     2.0              0.458           0.375              0.574
# 42224     2.0              0.458           0.375              0.580
# 42225     2.0              0.452           0.364              0.580
# 42226     2.0              0.452           0.364              0.580
#
#        Away 3PTRs PCT  Time Remaining Secs   WinProb         GameID
# 41802           0.000               2315.0  0.863339  19_02_22_4_27
# 41803           0.000               2315.0  0.863339  19_02_22_4_27
# 41804           0.000               2293.0  0.864061  19_02_22_4_27
# 41805           0.000               2293.0  0.864061  19_02_22_4_27
# 41806           0.000               2274.0  0.893199  19_02_22_4_27
# ...               ...                  ...       ...            ...
# 42222           0.522                 51.0  0.980118  19_02_22_4_27
# 42223           0.522                 51.0  0.980118  19_02_22_4_27
# 42224           0.542                 22.0  0.988547  19_02_22_4_27
# 42225           0.542                 16.0  0.988447  19_02_22_4_27
# 42226           0.542                 16.0  0.988447  19_02_22_4_27
#
# [425 rows x 12 columns]

# %%
# sub = pd.read_csv('sample_submission.csv')
# sub['target'] = clf.predict_proba(X_test)[:,1]
# sub['game_id'] = X_test.iloc[:,0]
# sub['game_id'] = sub['game_id'].ffill()
# # for i in range(1, len(sub)):
# #     #print(sub['game_id'][i])
# #     if sub['game_id'][i] == 'NaN':
# #         print('hi')
# #         sub['game_id'][i] = sub['game_id'][i - 1]
# print(sub)
sub.to_csv('submission.csv',index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np


def plotGraph(y_test,y_pred,regressorName):
    if max(y_test) >= max(y_pred):
        my_range = int(max(y_test))
    else:
        my_range = int(max(y_pred))
    plt.scatter(range(len(y_test)), y_test, color='blue')
    #plt.scatter(range(len(y_pred)), y_pred, color='red')
    plt.title(regressorName)
    plt.show()
    return


plotGraph(y_test[0:470], y_pred[0:470], "test")
